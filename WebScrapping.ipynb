# %%
# Importing libraries
from bs4 import BeautifulSoup
import requests
import psycopg2
import becas

# Starting a connection with postgres
conn = psycopg2.connect("dbname=postgres user=postgres")
conn.autocommit = True
# Making a cursor object
cur = conn.cursor()
#cur.execute("DROP TABLE GSE_data")
# Create table in database
cur.execute("CREATE TABLE GSE_data(GSE_Id varchar(7) PRIMARY KEY, Title text, Summary text, Organism text, Experiment_type text, Overall_design text, Citation text, Keyword text [], Unique_Identifier text [])")


# Required Authentication for becas API
becas.email = "kanshul03@gmail.com"


# Create a list of all the GSE_ID's whose information to scrape
GSE_Id = ["63312", "78224", "74018", "50734", "114644", "60477", "53599", "80582", "109493", "35200"]
for id in GSE_Id:
    # Request resources from the website
    response = requests.get("https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE{}".format(id))
    content = response.content
    # Parse the content from the website using BeautifulSoup
    parser = BeautifulSoup(content, "html.parser")
    # Below line will find all the occurances of <td> using the parser created above
    td = parser.find_all("td")
    
    # Create a dictionary to store all the information regarding a GSE_ID
    dic = {"GSE Id": id}
    # Parsing over the required content in the website and saving it in dictionary
    for i in range(38,99,2):
        dic[td[i].text] = td[i+1].text
    
    
    # List of elements that are required related to GSE_ID
    info = ["GSE Id", "Title", "Summary", "Organism", "Experiment type", "Overall design", "Citation(s)"]
    # Make a seperate dictionary with only the required elements as key and their description as values
    req_dic = {key: dic[key] for key in info}
    
    
    # Query to insert the collected data into database
    query = """INSERT INTO GSE_data (GSE_Id, Title, Summary, Organism, Experiment_type, Overall_design, Citation) VALUES (%s, %s, %s, %s, %s, %s, %s)"""
    record_to_insert = (req_dic["GSE Id"], req_dic["Title"], req_dic["Summary"], req_dic["Organism"], req_dic["Experiment type"], req_dic["Overall design"], req_dic["Citation(s)"])
    cur.execute(query, record_to_insert)
    
    
    # Annotate the summary text using Becas API
    json = becas.annotate_text(req_dic["Summary"])
    # Make a list of all the entity values from the resulted dictionary(json) after annotation
    entities_list = json["entities"]
    
    # Make empty list for keywords and unique_identifiers
    keyword = []
    unique_identifier = []
    
    for each in entities_list:
        # Split every element of entity_list into three parts using split on "|"
        each = each.split("|")
        # The first part is keyword
        keyword.append(each[0])
        # The second part is Unique Identifier
        # Many Keywords have multiple identifiers seperated by ";"
        # So split them and append each to the list
        each[1] = each[1].split(";")
        for identifier in each[1]:
            unique_identifier.append(identifier)
    
    
    # Query to add keywords and unique identifiers in the table for each GSE ID
    query = ("""UPDATE GSE_Data 
                SET Keyword = %s,
                unique_identifier = %s
                WHERE GSE_Id = %s
                """)
    record_to_insert = (keyword, unique_identifier, id)
    cur.execute(query, record_to_insert)

    
# Query to find GSE_Id's having Disease keyword.    
cur.execute("SELECT GSE_Id FROM GSE_Data WHERE array_to_string(unique_identifier, ',') LIKE '%DISO%'")
data = cur.fetchall()
print(data)


# Close the connection with the database
conn.close()
# Out:
# ['UMLS:C1704259:T044:PROC', 'UMLS:C0007621:T191:DISO', 'UMLS:C0023467:T191:DISO', 'UNIPROT:P41212:T116:PRGE', 'UMLS:C0023467:T191:DISO', 'UMLS:C0023467:T191:DISO', 'UMLS:C0023418:T191:DISO', 'NCBI:9606:T001:SPEC', 'UNIPROT:Q03164:T116:PRGE', 'UNIPROT:O60861:T116:PRGE', 'UNIPROT:P01111:T116:PRGE', 'GO:0010467::PROC', 'CHEBI:62488:T103:CHED', 'UMLS:C0023418:T191:DISO', 'GO:0010467::PROC', 'UNIPROT:P01116:T116:PRGE', 'CHEBI:63620:T103:CHED', 'UNIPROT:P01112:T116:PRGE', 'UNIPROT:P01116:T116:PRGE', 'CHEBI:63620:T103:CHED', 'UNIPROT:P01112:T116:PRGE', 'UMLS:C1956422:T025:ANAT', 'CHEBI:63620:T103:CHED', 'UNIPROT:Q03164:T116:PRGE', 'UNIPROT:O60861:T116:PRGE', 'UMLS:C1378511:T191:DISO', 'UMLS:C0280141:T191:DISO', 'UMLS:C1704259:T044:PROC', 'UMLS:C0023467:T191:DISO', 'GO:0007165::PROC', 'GO:0023052::PROC', 'CHEBI:35222:T103:CHED', 'UNIPROT:P45985:T116:PRGE', 'UNIPROT:O14733:T116:PRGE', 'CHEBI:28398:T103:CHED', 'UNIPROT:Q02750:T116:PRGE', 'UNIPROT:P52564:T116:PRGE', 'EC:2.7.12.2:T126:ENZY', 'UNIPROT:Q96KB5:T116:PRGE', 'UNIPROT:P36507:T116:PRGE', 'UNIPROT:Q13163:T116:PRGE', 'UNIPROT:P46734:T116:PRGE', 'UNIPROT:P42345:T116:PRGE', 'UMLS:C0596988:T049:DISO', 'GO:0007165::PROC', 'GO:0023052::PROC', 'NCBI:10090:T001:SPEC', 'UNIPROT:P01116:T116:PRGE', 'CHEBI:63620:T103:CHED', 'UNIPROT:P01112:T116:PRGE', 'UMLS:C2349967:T017:ANAT', 'UMLS:C0027651:T191:DISO', 'UMLS:C1704259:T044:PROC', 'GO:0005623::COMP', 'UMLS:C0023467:T191:DISO', 'UNIPROT:P01116:T116:PRGE', 'UNIPROT:P01112:T116:PRGE', 'UMLS:C1704259:T044:PROC', 'UMLS:C2825032:T048:DISO', 'UNIPROT:P10243:T116:PRGE', 'UMLS:C0006826:T191:DISO']
#
#
# []
#
#
# ['UNIPROT:Q03164:T116:PRGE', 'UNIPROT:O60861:T116:PRGE', 'UMLS:C0038250:T025:ANAT', 'UNIPROT:P52954:T116:PRGE', 'UNIPROT:Q03014:T116:PRGE', 'GO:0030097::PROC', 'UNIPROT:Q8N726:T116:PRGE', 'UNIPROT:P42771:T116:PRGE', 'GO:0005623::COMP', 'UMLS:C1325410:T043:PROC', 'GO:0051726::PROC', 'UMLS:C1171362:T045:PROC', 'UMLS:C1515670:T045:PROC', 'GO:0010467::PROC', 'BSID:529::PATH', 'UMLS:C0023467:T191:DISO', 'UMLS:C0333951:T046:DISO', 'UMLS:C0598766:T191:DISO', 'UMLS:C0525006:T042:PROC', 'UMLS:C1704259:T044:PROC', 'BSID:529::PATH', 'UMLS:C0023467:T191:DISO', 'UNIPROT:P09629:T116:PRGE', 'BSID:529::PATH', 'UMLS:C0023467:T191:DISO', 'UNIPROT:P41212:T116:PRGE', 'UMLS:C0027651:T191:DISO', 'GO:0030154::PROC', 'GO:0010467::PROC', 'CHEBI:46904:T103:CHED', 'GO:0005488::FUNC', 'UNIPROT:Q03014:T116:PRGE', 'UNIPROT:Q03111:T116:PRGE', 'UNIPROT:Q03014:T116:PRGE', 'UNIPROT:Q8N726:T116:PRGE', 'UNIPROT:P42771:T116:PRGE', 'UMLS:C1621966:T042:PROC', 'GO:0040007::PROC', 'UMLS:C1621966:T042:PROC', 'GO:0040007::PROC', 'UMLS:C0027651:T191:DISO', 'UNIPROT:P42771:T116:PRGE', 'UMLS:C0023467:T191:DISO']
#
#
# ['UNIPROT:P41212:T116:PRGE', 'GO:0010467::PROC', 'UMLS:C1292769:T191:DISO', 'CHEBI:50342:T103:CHED', 'GO:0005488::FUNC', 'CHEBI:30182:T103:CHED', 'UMLS:C1269647:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'GO:0019815::COMP', 'GO:0042571::COMP', 'UMLS:C1621287:T044:PROC', 'GO:0003823::FUNC', 'CHEBI:16541:T103:CHED', 'CHEBI:36080:T103:CHED', 'GO:0015074::PROC', 'UMLS:C0007600:T025:ANAT', 'GO:0005623::COMP', 'CHEBI:33709:T103:CHED', 'CHEBI:30182:T103:CHED', 'UNIPROT:P41212:T116:PRGE', 'CHEBI:16541:T103:CHED', 'CHEBI:36080:T103:CHED', 'NCBI:10090:T001:SPEC', 'CHEBI:30182:T103:CHED', 'UNIPROT:P41212:T116:PRGE']
#
#
# ['UMLS:C0277556:T047:DISO', 'NCBI:10090:T001:SPEC', 'CHEBI:27561:T103:CHED', 'CHEBI:36080:T103:CHED', 'GO:0097028::PROC', 'UMLS:C0599813:T043:PROC', 'GO:0071806::PROC', 'UMLS:C0599718:T043:PROC', 'UMLS:C0598766:T191:DISO', 'CHEBI:27561:T103:CHED', 'UMLS:C1171362:T045:PROC', 'UMLS:C1515670:T045:PROC', 'GO:0010467::PROC', 'UMLS:C0598766:T191:DISO', 'UNIPROT:Q9UNE7:T116:PRGE', 'UMLS:C0301625:T040:PROC', 'UMLS:C0221103:T046:DISO', 'UMLS:C0023467:T191:DISO', 'UNIPROT:P15884:T116:PRGE', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'UNIPROT:P02649:T116:PRGE', 'UNIPROT:P15923:T116:PRGE', 'UNIPROT:P15884:T116:PRGE', 'UNIPROT:P15884:T116:PRGE', 'UMLS:C0598766:T191:DISO', 'UNIPROT:P15884:T116:PRGE', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'UMLS:C0598766:T191:DISO', 'UNIPROT:Q99081:T116:PRGE', 'CHEBI:16541:T103:CHED', 'CHEBI:36080:T103:CHED', 'UMLS:C0023467:T191:DISO', 'UNIPROT:P15884:T116:PRGE', 'CHEBI:36080:T103:CHED', 'UNIPROT:P15884:T116:PRGE', 'UMLS:C0023418:T191:DISO', 'GO:0005488::FUNC', 'CHEBI:27561:T103:CHED', 'UNIPROT:P15884:T116:PRGE', 'UMLS:C0040715:T049:DISO', 'UMLS:C1512167:T045:PROC', 'UMLS:C0021469:T044:PROC', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'NCBI:9606:T001:SPEC', 'UNIPROT:P02649:T116:PRGE', 'UMLS:C0008633:T026:ANAT', 'GO:0005694::COMP', 'GO:0010467::PROC', 'CHEBI:16541:T103:CHED', 'CHEBI:36080:T103:CHED', 'UNIPROT:P40225:T116:PRGE', 'UMLS:C1621966:T042:PROC', 'GO:0040007::PROC', 'UMLS:C0678723:T040:PROC', 'GO:0032502::PROC', 'CHEBI:36080:T103:CHED', 'UNIPROT:Q99081:T116:PRGE', 'BSID:529::PATH', 'UMLS:C0023467:T191:DISO', 'GO:0006351::PROC', 'UMLS:C0040649:T045:PROC', 'GO:0005488::FUNC', 'UMLS:C0598766:T191:DISO', 'CHEBI:16541:T103:CHED', 'CHEBI:36080:T103:CHED', 'GO:0043234::COMP', 'UMLS:C1523872:T026:ANAT', 'UNIPROT:P15923:T116:PRGE', 'UMLS:C0598766:T191:DISO', 'UMLS:C0003315:T025:ANAT', 'UMLS:C1511762:T025:ANAT', 'UMLS:C0011306:T025:ANAT']
#
#
# ['GO:0006351::PROC', 'UMLS:C0040649:T045:PROC', 'CHEBI:26536:T103:CHED', 'CHEBI:15367:T103:CHED', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'CHEBI:16541:T103:CHED', 'CHEBI:36080:T103:CHED', 'CHEBI:36080:T103:CHED', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'UMLS:C0033572:T023:ANAT', 'UMLS:C1278980:T023:ANAT', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'UMLS:C1171362:T045:PROC', 'UMLS:C1515670:T045:PROC', 'GO:0010467::PROC', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'UMLS:C0023467:T191:DISO', 'UMLS:C0600139:T191:DISO', 'BSID:523::PATH', 'UMLS:C0376358:T191:DISO', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'UMLS:C0553580:T191:DISO', 'GO:0030154::PROC', 'UNIPROT:Q9Y5X4:T116:PRGE', 'UNIPROT:P35637:T116:PRGE', 'UNIPROT:P35637:T116:PRGE', 'GO:0030154::PROC', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'CHEBI:26536:T103:CHED', 'CHEBI:15367:T103:CHED', 'CHEBI:36080:T103:CHED', 'GO:0007165::PROC', 'UMLS:C0086982:T044:PROC', 'GO:0004886::FUNC', 'GO:0010467::PROC', 'GO:0005623::COMP', 'UNIPROT:P10276:T116:PRGE', 'UNIPROT:P35637:T116:PRGE', 'UNIPROT:P17542:T116:PRGE', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'UNIPROT:P12980:T116:PRGE', 'UNIPROT:P23769:T116:PRGE', 'UNIPROT:P35637:T116:PRGE', 'UMLS:C0018956:T025:ANAT', 'UMLS:C0038250:T025:ANAT', 'UNIPROT:P11308:T116:PRGE', 'UNIPROT:Q12809:T116:PRGE', 'UNIPROT:Q13045:T116:PRGE', 'UNIPROT:Q01543:T116:PRGE', 'CHEBI:36080:T103:CHED', 'GO:0010467::PROC', 'UMLS:C0006826:T191:DISO', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'UNIPROT:P20908:T116:PRGE']
#
#
# ['UMLS:C0334094:T046:DISO', 'UMLS:C0334094:T046:DISO', 'UNIPROT:P17844:T116:PRGE', 'UMLS:C0021469:T044:PROC', 'GO:0006915::PROC', 'GO:0097194::PROC', 'BSID:470::PATH', 'GO:0012501::PROC', 'UNIPROT:P17844:T116:PRGE', 'UMLS:C1269647:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'GO:0010467::PROC', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'GO:0008283::PROC', 'UMLS:C0040300:T024:ANAT', 'UMLS:C0007587:T043:PROC', 'GO:0008219::PROC', 'UMLS:C0021469:T044:PROC', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'UMLS:C1269647:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'UMLS:C0021469:T044:PROC', 'UMLS:C0021469:T044:PROC', 'UNIPROT:P17844:T116:PRGE']
#
#
# ['UMLS:C1158770:T045:PROC', 'GO:0006355::PROC', 'CHEBI:27561:T103:CHED', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'UMLS:C0598766:T191:DISO', 'NCBI:9606:T001:SPEC', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'CHEBI:27561:T103:CHED', 'NCBI:9606:T001:SPEC', 'UNIPROT:Q08117:T116:PRGE', 'CHEBI:16704:T103:CHED', 'CHEBI:59061:T103:CHED']
#
#
# []
#
#
# ['UMLS:C0699040:T026:ANAT', 'GO:0009986::COMP', 'UMLS:C0023467:T191:DISO', 'CHEBI:46941:T103:CHED', 'EC:2.7.11.26:T126:ENZY', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'GO:0050321::FUNC', 'UMLS:C0301625:T040:PROC', 'UMLS:C0221103:T046:DISO', 'GO:0030154::PROC', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'GO:0030154::PROC', 'BSID:470::PATH', 'GO:0043065::PROC', 'GO:0006917::PROC', 'UMLS:C0023467:T191:DISO', 'UMLS:C0085669:T191:DISO', 'UMLS:C0023467:T191:DISO', 'EC:2.7.11.26:T126:ENZY', 'GO:0050321::FUNC', 'UMLS:C0023467:T191:DISO', 'CHEBI:53448:T103:CHED', 'UMLS:C1512310:T025:ANAT', 'BSID:463::PATH', 'UMLS:C1621966:T042:PROC', 'GO:0040007::PROC', 'UMLS:C0023467:T191:DISO', 'UMLS:C0023467:T191:DISO', 'UMLS:C0006826:T191:DISO', 'UMLS:C0006826:T191:DISO', 'CHEBI:26986:T103:CHED', 'CHEBI:16857:T103:CHED', 'EC:2.4.1.21:T126:ENZY', 'EC:2.7.11.26:T126:ENZY', 'GO:0050321::FUNC', 'GO:0015074::PROC', 'UMLS:C0023467:T191:DISO', 'UMLS:C0007600:T025:ANAT', 'EC:2.7.11.26:T126:ENZY', 'GO:0050321::FUNC', 'GO:0010467::PROC', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'BSID:529::PATH', 'UMLS:C0023467:T191:DISO', 'EC:2.7.11.26:T126:ENZY', 'GO:0050321::FUNC', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'UMLS:C0334094:T046:DISO', 'UMLS:C0334094:T046:DISO', 'EC:2.7.11.26:T126:ENZY', 'GO:0050321::FUNC', 'CHEBI:17822:T103:CHED', 'CHEBI:17115:T103:CHED', 'GO:0030154::PROC', 'UMLS:C0678723:T040:PROC', 'GO:0032502::PROC', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'GO:0005623::COMP', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'UMLS:C0023467:T191:DISO', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'UNIPROT:O14965:T116:PRGE', 'UMLS:C3282337:T025:ANAT', 'GO:0005623::COMP', 'UMLS:C0007634:T025:ANAT', 'EC:2.7.11.26:T126:ENZY', 'GO:0050321::FUNC', 'GO:0009058::PROC', 'UNIPROT:P49841:T116:PRGE', 'UNIPROT:P49840:T116:PRGE', 'GO:0010467::PROC', 'GO:0051726::PROC', 'GO:0010564::PROC', 'UNIPROT:P13807:T116:PRGE', 'UNIPROT:P54840:T116:PRGE', 'UNIPROT:P41212:T116:PRGE', 'UMLS:C0023467:T191:DISO', 'GO:0010467::PROC', 'UMLS:C0678723:T040:PROC', 'GO:0032502::PROC', 'UMLS:C1254042:T039:PROC', 'UNIPROT:P41212:T116:PRGE', 'GO:0007165::PROC', 'UMLS:C0023467:T191:DISO', 'UMLS:C1269647:T025:ANAT', 'UMLS:C0007634:T025:ANAT', 'UMLS:C0684336:T046:DISO', 'EC:2.7.11.26:T126:ENZY', 'GO:0050321::FUNC']
#
#
# [('63312',), ('74018',), ('50734',), ('114644',), ('60477',), ('53599',), ('80582',), ('35200',)]
